# %%
import yfinance as yf

# %%
msft = yf.Ticker("9101.T")

# %%
msft
# Out:
# yfinance.Ticker object <9101.T>

# %%
msft.info
# Out:
# {'zip': '100-0005',
#  'sector': 'Industrials',
#  'fullTimeEmployees': 35057,
# ...
